# %% [markdown]
# # Create Data Dictionary

# %% [markdown]
# Export the Farm Data Model as an Excel Spread Sheet

# %% [markdown]
# #### Import statments

# %%
import json
import csv

# %% [markdown]
# #### Set paths and load in Data Model

# %%
basePath = r'C:\Users\rjc.EAGLE\Documents\GitHub\AgricultureDataModel'

data = {}
data.update(json.load(open('{0}\\json\\{1}.json'.format(basePath, 'datamodel'))))
data.update(json.load(open('{0}\\json\\{1}.json'.format(basePath, 'tables'))))
data.update(json.load(open('{0}\\json\\{1}.json'.format(basePath, 'domains'))))
data
# Out:
# {'services': [{'name': 'administrative_information',
#    'alias': 'Administrative Information',
#    'tables': ['activities', 'additional_details', 'measurements', 'staff'],
#    'layers': [{'name': 'access_points',
#      'alias': 'Access Points',
#      'type': 'POINT',
#      'children': ['activities'],
#      'fields': [{'name': 'name',
#        'alias': 'Address',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'alias',
#        'alias': 'Alias',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'unique_number',
#        'alias': 'Unique Number',
#        'type': 'SHORT',
#        'length': None,
#        'domain': None},
#       {'name': 'status',
#        'alias': 'Status',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'status'},
#       {'name': 'start_date',
#        'alias': 'Start Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'end_date',
#        'alias': 'End Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'class',
#        'alias': 'Class',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'primary_secondary'},
#       {'name': 'notes',
#        'alias': 'Notes',
#        'type': 'TEXT',
#        'length': 1000,
#        'domain': None}],
#      'drawingInfo': {'transparency': 0,
#       'scaleSymbols': True,
#       'renderer': {'type': 'uniqueValue',
#        'field1': 'class',
#        'uniqueValueInfos': [{'value': 'Primary',
#          'symbol': {'type': 'esriSMS',
#           'style': 'esriSMSCircle',
#           'size': 20,
#           'color': [46, 188, 252, 255],
#           'outline': {'color': [32, 32, 32, 255], 'width': 2}}}],
#        'defaultLabel': 'Default',
#        'defaultSymbol': {'type': 'esriSMS',
#         'style': 'esriSMSCircle',
#         'size': 20,
#         'color': [232, 232, 232, 255],
#         'outline': {'color': [32, 32, 32, 255], 'width': 2}}},
#       'labelingInfo': None}},
#     {'name': 'blocks',
#      'alias': 'Blocks',
#      'type': 'POLYGON',
#      'children': ['activities'],
#      'fields': [{'name': 'name',
#        'alias': 'Name',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'alias',
#        'alias': 'Alias',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'unique_number',
#        'alias': 'Unique Number',
#        'type': 'SHORT',
#        'length': None,
#        'domain': None},
#       {'name': 'status',
#        'alias': 'Status',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'status'},
#       {'name': 'start_date',
#        'alias': 'Start Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'end_date',
#        'alias': 'End Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'class',
#        'alias': 'Class',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'block_class'},
#       {'name': 'subclass',
#        'alias': 'Subclass',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'productive',
#        'alias': 'Productive',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'yes_no'},
#       {'name': 'protected',
#        'alias': 'Protected',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'yes_no'},
#       {'name': 'notes',
#        'alias': 'Notes',
#        'type': 'TEXT',
#        'length': 1000,
#        'domain': None}],
#      'drawingInfo': {'transparency': 0,
#       'scaleSymbols': True,
#       'renderer': {'type': 'uniqueValue',
#        'field1': 'class',
#        'uniqueValueInfos': [{'value': 'Primary',
#          'symbol': {'type': 'esriSFS',
#           'style': 'esriSFSNull',
#           'color': None,
#           'outline': {'type': 'esriSLS',
#            'style': 'esriSLSSolid',
#            'color': [250, 250, 250, 250],
#            'width': 1}}}],
#        'defaultLabel': 'Default',
#        'defaultSymbol': {'type': 'esriSFS',
#         'style': 'esriSFSSolid',
#         'color': [46, 188, 252, 255],
#         'outline': {'type': 'esriSLS',
#          'style': 'esriSLSSolid',
#          'color': [250, 250, 250, 255],
#          'width': 1}}},
#       'labelingInfo': None}},
#     {'name': 'site',
#      'alias': 'Site',
#      'type': 'POLYGON',
#      'children': ['blocks',
#       'access_points',
#       'activities',
#       'additional_details',
#       'measurements',
#       'staff'],
#      'fields': [{'name': 'name',
#        'alias': 'Name',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'alias',
#        'alias': 'Alias',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'unique_number',
#        'alias': 'Unique Number',
#        'type': 'SHORT',
#        'length': None,
#        'domain': None},
#       {'name': 'status',
#        'alias': 'Status',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'status'},
#       {'name': 'start_date',
#        'alias': 'Start Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'end_date',
#        'alias': 'End Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'class',
#        'alias': 'Class',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'site_class'},
#       {'name': 'subclass',
#        'alias': 'Subclass',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'primary_secondary'},
#       {'name': 'capacity',
#        'alias': 'Capacity',
#        'type': 'SHORT',
#        'length': None,
#        'domain': None},
#       {'name': 'unit',
#        'alias': 'Unit',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'units'},
#       {'name': 'usage',
#        'alias': 'Usage',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'notes',
#        'alias': 'Notes',
#        'type': 'TEXT',
#        'length': 1000,
#        'domain': None}],
#      'drawingInfo': {'transparency': 0,
#       'scaleSymbols': True,
#       'renderer': {'type': 'uniqueValue',
#        'field1': 'class',
#        'uniqueValueInfos': [{'value': 'Primary',
#          'symbol': {'type': 'esriSFS',
#           'style': 'esriSFSNull',
#           'color': None,
#           'outline': {'type': 'esriSLS',
#            'style': 'esriSLSSolid',
#            'color': [250, 250, 250, 250],
#            'width': 1}}}],
#        'defaultLabel': 'Default',
#        'defaultSymbol': {'type': 'esriSFS',
#         'style': 'esriSFSSolid',
#         'color': [46, 188, 252, 255],
#         'outline': {'type': 'esriSLS',
#          'style': 'esriSLSSolid',
#          'color': [250, 250, 250, 255],
#          'width': 1}}},
#       'labelingInfo': None}},
#     {'name': 'holding',
#      'alias': 'Holding',
#      'type': 'POLYGON',
#      'children': ['site'],
#      'fields': [{'name': 'name',
#        'alias': 'Name',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'alias',
#        'alias': 'Alias',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'start_date',
#        'alias': 'Start Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'end_date',
#        'alias': 'End Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'owner',
#        'alias': 'Owner',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'titles',
#        'alias': 'Titles',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'notes',
#        'alias': 'Notes',
#        'type': 'TEXT',
#        'length': 1000,
#        'domain': None}],
#      'drawingInfo': {'transparency': 0,
#       'scaleSymbols': True,
#       'renderer': {'type': 'uniqueValue',
#        'field1': 'class',
#        'uniqueValueInfos': [{'value': 'Primary',
#          'symbol': {'type': 'esriSFS',
#           'style': 'esriSFSNull',
#           'color': None,
#           'outline': {'type': 'esriSLS',
#            'style': 'esriSLSSolid',
#            'color': [250, 250, 250, 250],
#            'width': 1}}}],
#        'defaultLabel': 'Default',
#        'defaultSymbol': {'type': 'esriSFS',
#         'style': 'esriSFSSolid',
#         'color': [46, 188, 252, 255],
#         'outline': {'type': 'esriSLS',
#          'style': 'esriSLSSolid',
#          'color': [250, 250, 250, 255],
#          'width': 1}}},
#       'labelingInfo': None}}]},
#   {'name': 'structures',
#    'alias': 'Structures',
#    'tables': ['activities', 'additional_details', 'hazards', 'measurements'],
#    'layers': [{'name': 'production_structures',
#      'alias': 'Production Structures',
#      'type': 'POINT',
#      'children': ['activities',
#       'additional_details',
#       'hazards',
#       'measurements'],
#      'fields': [{'name': 'name',
#        'alias': 'Name',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'alias',
#        'alias': 'Alias',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'unique_number',
#        'alias': 'Unique Number',
#        'type': 'SHORT',
#        'length': None,
#        'domain': None},
#       {'name': 'status',
#        'alias': 'Status',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'status'},
#       {'name': 'start_date',
#        'alias': 'Start Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'end_date',
#        'alias': 'End Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'class',
#        'alias': 'Class',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'production_structure_class'},
#       {'name': 'subclass',
#        'alias': 'Subclass',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'production_structure_subclass'},
#       {'name': 'capacity',
#        'alias': 'Capacity',
#        'type': 'DOUBLE',
#        'length': None,
#        'domain': None},
#       {'name': 'unit',
#        'alias': 'Unit',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'units'},
#       {'name': 'usage',
#        'alias': 'Usage',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'material',
#        'alias': 'Material',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'material'},
#       {'name': 'notes',
#        'alias': 'Notes',
#        'type': 'TEXT',
#        'length': 1000,
#        'domain': None}],
#      'drawingInfo': {'transparency': 0,
#       'scaleSymbols': True,
#       'renderer': {'type': 'uniqueValue',
#        'field1': 'class',
#        'uniqueValueInfos': [{'value': 'Primary',
#          'symbol': {'type': 'esriSMS',
#           'style': 'esriSMSCircle',
#           'size': 20,
#           'color': [46, 188, 252, 255],
#           'outline': {'color': [32, 32, 32, 255], 'width': 2}}}],
#        'defaultLabel': 'Default',
#        'defaultSymbol': {'type': 'esriSMS',
#         'style': 'esriSMSCircle',
#         'size': 20,
#         'color': [232, 232, 232, 255],
#         'outline': {'color': [32, 32, 32, 255], 'width': 2}}},
#       'labelingInfo': None}},
#     {'name': 'storage_structures',
#      'alias': 'Storage Structures',
#      'type': 'POINT',
#      'children': ['activities', 'hazards', 'measurements'],
#      'fields': [{'name': 'name',
#        'alias': 'Name',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'alias',
#        'alias': 'Alias',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'unique_number',
#        'alias': 'Unique Number',
#        'type': 'SHORT',
#        'length': None,
#        'domain': None},
#       {'name': 'status',
#        'alias': 'Status',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'status'},
#       {'name': 'start_date',
#        'alias': 'Start Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'end_date',
#        'alias': 'End Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'content',
#        'alias': 'Content',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'content_type'},
#       {'name': 'class',
#        'alias': 'Class',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'storage_structure_class'},
#       {'name': 'subclass',
#        'alias': 'Subclass',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'capacity',
#        'alias': 'Capacity',
#        'type': 'DOUBLE',
#        'length': None,
#        'domain': None},
#       {'name': 'unit',
#        'alias': 'Unit',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'units'},
#       {'name': 'usage',
#        'alias': 'Usage',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'material',
#        'alias': 'Material',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'material'},
#       {'name': 'notes',
#        'alias': 'Notes',
#        'type': 'TEXT',
#        'length': 1000,
#        'domain': None}],
#      'drawingInfo': {'transparency': 0,
#       'scaleSymbols': True,
#       'renderer': {'type': 'uniqueValue',
#        'field1': 'class',
#        'uniqueValueInfos': [{'value': 'Primary',
#          'symbol': {'type': 'esriSMS',
#           'style': 'esriSMSCircle',
#           'size': 20,
#           'color': [46, 188, 252, 255],
#           'outline': {'color': [32, 32, 32, 255], 'width': 2}}}],
#        'defaultLabel': 'Default',
#        'defaultSymbol': {'type': 'esriSMS',
#         'style': 'esriSMSCircle',
#         'size': 20,
#         'color': [232, 232, 232, 255],
#         'outline': {'color': [32, 32, 32, 255], 'width': 2}}},
#       'labelingInfo': None}},
#     {'name': 'service_structures',
#      'alias': 'Service Structures',
#      'type': 'POINT',
#      'children': ['activities', 'hazards', 'measurements'],
#      'fields': [{'name': 'name',
#        'alias': 'Name',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'alias',
#        'alias': 'Alias',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'unique_number',
#        'alias': 'Unique Number',
#        'type': 'SHORT',
#        'length': None,
#        'domain': None},
#       {'name': 'status',
#        'alias': 'Status',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'status'},
#       {'name': 'start_date',
#        'alias': 'Start Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'end_date',
#        'alias': 'End Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'class',
#        'alias': 'Class',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'service_structure_class'},
#       {'name': 'subclass',
#        'alias': 'Subclass',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'capacity',
#        'alias': 'Capacity',
#        'type': 'DOUBLE',
#        'length': None,
#        'domain': None},
#       {'name': 'unit',
#        'alias': 'Unit',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'units'},
#       {'name': 'usage',
#        'alias': 'Usage',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'material',
#        'alias': 'Material',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'material'},
#       {'name': 'notes',
#        'alias': 'Notes',
#        'type': 'TEXT',
#        'length': 1000,
#        'domain': None}],
#      'drawingInfo': {'transparency': 0,
#       'scaleSymbols': True,
#       'renderer': {'type': 'uniqueValue',
#        'field1': 'class',
#        'uniqueValueInfos': [{'value': 'Primary',
#          'symbol': {'type': 'esriSMS',
#           'style': 'esriSMSCircle',
#           'size': 20,
#           'color': [46, 188, 252, 255],
#           'outline': {'color': [32, 32, 32, 255], 'width': 2}}}],
#        'defaultLabel': 'Default',
#        'defaultSymbol': {'type': 'esriSMS',
#         'style': 'esriSMSCircle',
#         'size': 20,
#         'color': [232, 232, 232, 255],
#         'outline': {'color': [32, 32, 32, 255], 'width': 2}}},
#       'labelingInfo': None}},
#     {'name': 'management_structures',
#      'alias': 'Management Structures',
#      'type': 'POINT',
#      'children': ['activities', 'hazards', 'measurements'],
#      'fields': [{'name': 'name',
#        'alias': 'Name',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'alias',
#        'alias': 'Alias',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'unique_number',
#        'alias': 'Unique Number',
#        'type': 'SHORT',
#        'length': None,
#        'domain': None},
#       {'name': 'status',
#        'alias': 'Status',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'status'},
#       {'name': 'start_date',
#        'alias': 'Start Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'end_date',
#        'alias': 'End Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'class',
#        'alias': 'Class',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'management_structure_class'},
#       {'name': 'subclass',
#        'alias': 'Subclass',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'usage',
#        'alias': 'Usage',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'material',
#        'alias': 'Material',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'material'},
#       {'name': 'notes',
#        'alias': 'Notes',
#        'type': 'TEXT',
#        'length': 1000,
#        'domain': None}],
#      'drawingInfo': {'transparency': 0,
#       'scaleSymbols': True,
#       'renderer': {'type': 'uniqueValue',
#        'field1': 'class',
#        'uniqueValueInfos': [{'value': 'Primary',
#          'symbol': {'type': 'esriSMS',
#           'style': 'esriSMSCircle',
#           'size': 20,
#           'color': [46, 188, 252, 255],
#           'outline': {'color': [32, 32, 32, 255], 'width': 2}}}],
#        'defaultLabel': 'Default',
#        'defaultSymbol': {'type': 'esriSMS',
#         'style': 'esriSMSCircle',
#         'size': 20,
#         'color': [232, 232, 232, 255],
#         'outline': {'color': [32, 32, 32, 255], 'width': 2}}},
#       'labelingInfo': None}},
#     {'name': 'waste_structures',
#      'alias': 'Waste Structures',
#      'type': 'POINT',
#      'children': ['activities', 'hazards', 'measurements'],
#      'fields': [{'name': 'name',
#        'alias': 'Name',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'alias',
#        'alias': 'Alias',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'unique_number',
#        'alias': 'Unique Number',
#        'type': 'SHORT',
#        'length': None,
#        'domain': None},
#       {'name': 'status',
#        'alias': 'Status',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'status'},
#       {'name': 'start_date',
#        'alias': 'Start Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'end_date',
#        'alias': 'End Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'class',
#        'alias': 'Class',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'waste_structure_class'},
#       {'name': 'subclass',
#        'alias': 'Subclass',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'capacity',
#        'alias': 'Capacity',
#        'type': 'DOUBLE',
#        'length': None,
#        'domain': None},
#       {'name': 'unit',
#        'alias': 'Unit',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'units'},
#       {'name': 'usage',
#        'alias': 'Usage',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'material',
#        'alias': 'Material',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'material'},
#       {'name': 'notes',
#        'alias': 'Notes',
#        'type': 'TEXT',
#        'length': 1000,
#        'domain': None}],
#      'drawingInfo': {'transparency': 0,
#       'scaleSymbols': True,
#       'renderer': {'type': 'uniqueValue',
#        'field1': 'class',
#        'uniqueValueInfos': [{'value': 'Primary',
#          'symbol': {'type': 'esriSMS',
#           'style': 'esriSMSCircle',
#           'size': 20,
#           'color': [46, 188, 252, 255],
#           'outline': {'color': [32, 32, 32, 255], 'width': 2}}}],
#        'defaultLabel': 'Default',
#        'defaultSymbol': {'type': 'esriSMS',
#         'style': 'esriSMSCircle',
#         'size': 20,
#         'color': [232, 232, 232, 255],
#         'outline': {'color': [32, 32, 32, 255], 'width': 2}}},
#       'labelingInfo': None}}]},
#   {'name': 'operations',
#    'alias': 'Operations',
#    'tables': ['activities', 'hazards'],
#    'layers': [{'name': 'operational_points',
#      'alias': 'Operational Points',
#      'type': 'POINT',
#      'children': ['activities', 'hazards'],
#      'fields': [{'name': 'name',
#        'alias': 'Name',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'alias',
#        'alias': 'Alias',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'unique_number',
#        'alias': 'Unique Number',
#        'type': 'SHORT',
#        'length': None,
#        'domain': None},
#       {'name': 'status',
#        'alias': 'Status',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'status'},
#       {'name': 'start_date',
#        'alias': 'Start Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'end_date',
#        'alias': 'End Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'class',
#        'alias': 'Class',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'operation_type'},
#       {'name': 'subclass',
#        'alias': 'Subclass',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'notes',
#        'alias': 'Notes',
#        'type': 'TEXT',
#        'length': 1000,
#        'domain': None}],
#      'drawingInfo': {'transparency': 0,
#       'scaleSymbols': True,
#       'renderer': {'type': 'uniqueValue',
#        'field1': 'class',
#        'uniqueValueInfos': [{'value': 'Primary',
#          'symbol': {'type': 'esriSMS',
#           'style': 'esriSMSCircle',
#           'size': 20,
#           'color': [46, 188, 252, 255],
#           'outline': {'color': [32, 32, 32, 255], 'width': 2}}}],
#        'defaultLabel': 'Default',
#        'defaultSymbol': {'type': 'esriSMS',
#         'style': 'esriSMSCircle',
#         'size': 20,
#         'color': [232, 232, 232, 255],
#         'outline': {'color': [32, 32, 32, 255], 'width': 2}}},
#       'labelingInfo': None}},
#     {'name': 'operational_lines',
#      'alias': 'Operational Lines',
#      'type': 'POLYLINE',
#      'children': ['activities', 'hazards'],
#      'fields': [{'name': 'name',
#        'alias': 'Name',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'alias',
#        'alias': 'Alias',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'unique_number',
#        'alias': 'Unique Number',
#        'type': 'SHORT',
#        'length': None,
#        'domain': None},
#       {'name': 'status',
#        'alias': 'Status',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'status'},
#       {'name': 'start_date',
#        'alias': 'Start Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'end_date',
#        'alias': 'End Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'class',
#        'alias': 'Class',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'operation_type'},
#       {'name': 'subclass',
#        'alias': 'Subclass',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'notes',
#        'alias': 'Notes',
#        'type': 'TEXT',
#        'length': 1000,
#        'domain': None}],
#      'drawingInfo': {'transparency': 0,
#       'scaleSymbols': True,
#       'renderer': {'type': 'uniqueValue',
#        'field1': 'class',
#        'uniqueValueInfos': [{'value': 'Primary',
#          'symbol': {'type': 'esriSLS',
#           'style': 'esriSLSSolid',
#           'color': [46, 188, 252, 255],
#           'width': 1}}],
#        'defaultLabel': 'Default',
#        'defaultSymbol': {'type': 'esriSLS',
#         'style': 'esriSLSSolid',
#         'color': [250, 250, 250, 255],
#         'width': 1}},
#       'labelingInfo': None}},
#     {'name': 'operational_areas',
#      'alias': 'Operational Areas',
#      'type': 'POLYGON',
#      'children': ['activities', 'hazards'],
#      'fields': [{'name': 'name',
#        'alias': 'Name',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'alias',
#        'alias': 'Alias',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'unique_number',
#        'alias': 'Unique Number',
#        'type': 'SHORT',
#        'length': None,
#        'domain': None},
#       {'name': 'status',
#        'alias': 'Status',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'status'},
#       {'name': 'start_date',
#        'alias': 'Start Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'end_date',
#        'alias': 'End Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'class',
#        'alias': 'Class',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'operation_type'},
#       {'name': 'subclass',
#        'alias': 'Subclass',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'notes',
#        'alias': 'Notes',
#        'type': 'TEXT',
#        'length': 1000,
#        'domain': None}],
#      'drawingInfo': {'transparency': 0,
#       'scaleSymbols': True,
#       'renderer': {'type': 'uniqueValue',
#        'field1': 'class',
#        'uniqueValueInfos': [{'value': 'Primary',
#          'symbol': {'type': 'esriSFS',
#           'style': 'esriSFSNull',
#           'color': None,
#           'outline': {'type': 'esriSLS',
#            'style': 'esriSLSSolid',
#            'color': [250, 250, 250, 250],
#            'width': 1}}}],
#        'defaultLabel': 'Default',
#        'defaultSymbol': {'type': 'esriSFS',
#         'style': 'esriSFSSolid',
#         'color': [46, 188, 252, 255],
#         'outline': {'type': 'esriSLS',
#          'style': 'esriSLSSolid',
#          'color': [250, 250, 250, 255],
#          'width': 1}}},
#       'labelingInfo': None}}]},
#   {'name': 'transport',
#    'alias': 'Transport',
#    'tables': ['activities', 'hazards'],
#    'layers': [{'name': 'transport_node',
#      'alias': 'Transport Node',
#      'type': 'POINT',
#      'children': ['activities', 'hazards'],
#      'fields': [{'name': 'name',
#        'alias': 'Name',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'alias',
#        'alias': 'Alias',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'unique_number',
#        'alias': 'Unique Number',
#        'type': 'SHORT',
#        'length': None,
#        'domain': None},
#       {'name': 'status',
#        'alias': 'Status',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'status'},
#       {'name': 'start_date',
#        'alias': 'Start Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'end_date',
#        'alias': 'End Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'class',
#        'alias': 'Class',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'transport_node_class'},
#       {'name': 'subclass',
#        'alias': 'Subclass',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'capacity',
#        'alias': 'Capacity',
#        'type': 'DOUBLE',
#        'length': None,
#        'domain': None},
#       {'name': 'unit',
#        'alias': 'Unit',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'units'},
#       {'name': 'material',
#        'alias': 'Material',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'material'},
#       {'name': 'notes',
#        'alias': 'Notes',
#        'type': 'TEXT',
#        'length': 1000,
#        'domain': None}],
#      'drawingInfo': {'transparency': 0,
#       'scaleSymbols': True,
#       'renderer': {'type': 'uniqueValue',
#        'field1': 'class',
#        'uniqueValueInfos': [{'value': 'Primary',
#          'symbol': {'type': 'esriSMS',
#           'style': 'esriSMSCircle',
#           'size': 20,
#           'color': [46, 188, 252, 255],
#           'outline': {'color': [32, 32, 32, 255], 'width': 2}}}],
#        'defaultLabel': 'Default',
#        'defaultSymbol': {'type': 'esriSMS',
#         'style': 'esriSMSCircle',
#         'size': 20,
#         'color': [232, 232, 232, 255],
#         'outline': {'color': [32, 32, 32, 255], 'width': 2}}},
#       'labelingInfo': None}},
#     {'name': 'transport_network',
#      'alias': 'Transport Network',
#      'type': 'POLYLINE',
#      'children': ['activities', 'hazards'],
#      'fields': [{'name': 'name',
#        'alias': 'Name',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'alias',
#        'alias': 'Alias',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'unique_number',
#        'alias': 'Unique Number',
#        'type': 'SHORT',
#        'length': None,
#        'domain': None},
#       {'name': 'status',
#        'alias': 'Status',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'status'},
#       {'name': 'start_date',
#        'alias': 'Start Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'end_date',
#        'alias': 'End Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'class',
#        'alias': 'Class',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'primary_secondary'},
#       {'name': 'subclass',
#        'alias': 'Subclass',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'material',
#        'alias': 'Material',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'material'},
#       {'name': 'notes',
#        'alias': 'Notes',
#        'type': 'TEXT',
#        'length': 1000,
#        'domain': None}],
#      'drawingInfo': {'transparency': 0,
#       'scaleSymbols': True,
#       'renderer': {'type': 'uniqueValue',
#        'field1': 'class',
#        'uniqueValueInfos': [{'value': 'Primary',
#          'symbol': {'type': 'esriSLS',
#           'style': 'esriSLSSolid',
#           'color': [46, 188, 252, 255],
#           'width': 1}}],
#        'defaultLabel': 'Default',
#        'defaultSymbol': {'type': 'esriSLS',
#         'style': 'esriSLSSolid',
#         'color': [250, 250, 250, 255],
#         'width': 1}},
#       'labelingInfo': None}}]},
#   {'name': 'electric_utilities',
#    'alias': 'Electric Utilities',
#    'tables': ['activities', 'hazards', 'measurements'],
#    'layers': [{'name': 'electric_device',
#      'alias': 'Electric Device',
#      'type': 'POINT',
#      'children': ['activities', 'hazards'],
#      'fields': [{'name': 'name',
#        'alias': 'Name',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'alias',
#        'alias': 'Alias',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'unique_number',
#        'alias': 'Unique Number',
#        'type': 'SHORT',
#        'length': None,
#        'domain': None},
#       {'name': 'status',
#        'alias': 'Status',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'status'},
#       {'name': 'start_date',
#        'alias': 'Start Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'end_date',
#        'alias': 'End Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'class',
#        'alias': 'Class',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'electric_device_class'},
#       {'name': 'subclass',
#        'alias': 'Subclass',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'capacity',
#        'alias': 'Capacity',
#        'type': 'DOUBLE',
#        'length': None,
#        'domain': None},
#       {'name': 'unit',
#        'alias': 'Unit',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'units'},
#       {'name': 'notes',
#        'alias': 'Notes',
#        'type': 'TEXT',
#        'length': 1000,
#        'domain': None}],
#      'drawingInfo': {'transparency': 0,
#       'scaleSymbols': True,
#       'renderer': {'type': 'uniqueValue',
#        'field1': 'class',
#        'uniqueValueInfos': [{'value': 'Primary',
#          'symbol': {'type': 'esriSMS',
#           'style': 'esriSMSCircle',
#           'size': 20,
#           'color': [46, 188, 252, 255],
#           'outline': {'color': [32, 32, 32, 255], 'width': 2}}}],
#        'defaultLabel': 'Default',
#        'defaultSymbol': {'type': 'esriSMS',
#         'style': 'esriSMSCircle',
#         'size': 20,
#         'color': [232, 232, 232, 255],
#         'outline': {'color': [32, 32, 32, 255], 'width': 2}}},
#       'labelingInfo': None}},
#     {'name': 'electric_junction',
#      'alias': 'Electric Junction',
#      'type': 'POINT',
#      'children': ['activities', 'hazards'],
#      'fields': [{'name': 'name',
#        'alias': 'Name',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'alias',
#        'alias': 'Alias',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'unique_number',
#        'alias': 'Unique Number',
#        'type': 'SHORT',
#        'length': None,
#        'domain': None},
#       {'name': 'status',
#        'alias': 'Status',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'status'},
#       {'name': 'start_date',
#        'alias': 'Start Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'end_date',
#        'alias': 'End Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'class',
#        'alias': 'Class',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'electric_junction_class'},
#       {'name': 'subclass',
#        'alias': 'Subclass',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'material',
#        'alias': 'Material',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'material'},
#       {'name': 'notes',
#        'alias': 'Notes',
#        'type': 'TEXT',
#        'length': 1000,
#        'domain': None}],
#      'drawingInfo': {'transparency': 0,
#       'scaleSymbols': True,
#       'renderer': {'type': 'uniqueValue',
#        'field1': 'class',
#        'uniqueValueInfos': [{'value': 'Primary',
#          'symbol': {'type': 'esriSMS',
#           'style': 'esriSMSCircle',
#           'size': 20,
#           'color': [46, 188, 252, 255],
#           'outline': {'color': [32, 32, 32, 255], 'width': 2}}}],
#        'defaultLabel': 'Default',
#        'defaultSymbol': {'type': 'esriSMS',
#         'style': 'esriSMSCircle',
#         'size': 20,
#         'color': [232, 232, 232, 255],
#         'outline': {'color': [32, 32, 32, 255], 'width': 2}}},
#       'labelingInfo': None}},
#     {'name': 'electric_structure',
#      'alias': 'Electric Structure',
#      'type': 'POINT',
#      'children': ['activities', 'hazards'],
#      'fields': [{'name': 'name',
#        'alias': 'Name',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'alias',
#        'alias': 'Alias',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'unique_number',
#        'alias': 'Unique Number',
#        'type': 'SHORT',
#        'length': None,
#        'domain': None},
#       {'name': 'status',
#        'alias': 'Status',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'status'},
#       {'name': 'start_date',
#        'alias': 'Start Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'end_date',
#        'alias': 'End Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'class',
#        'alias': 'Class',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'electric_structure_class'},
#       {'name': 'subclass',
#        'alias': 'Subclass',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'material',
#        'alias': 'Material',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'material'},
#       {'name': 'notes',
#        'alias': 'Notes',
#        'type': 'TEXT',
#        'length': 1000,
#        'domain': None}],
#      'drawingInfo': {'transparency': 0,
#       'scaleSymbols': True,
#       'renderer': {'type': 'uniqueValue',
#        'field1': 'class',
#        'uniqueValueInfos': [{'value': 'Primary',
#          'symbol': {'type': 'esriSMS',
#           'style': 'esriSMSCircle',
#           'size': 20,
#           'color': [46, 188, 252, 255],
#           'outline': {'color': [32, 32, 32, 255], 'width': 2}}}],
#        'defaultLabel': 'Default',
#        'defaultSymbol': {'type': 'esriSMS',
#         'style': 'esriSMSCircle',
#         'size': 20,
#         'color': [232, 232, 232, 255],
#         'outline': {'color': [32, 32, 32, 255], 'width': 2}}},
#       'labelingInfo': None}},
#     {'name': 'electric_network',
#      'alias': 'Electric Network',
#      'type': 'POLYLINE',
#      'children': ['activities', 'hazards'],
#      'fields': [{'name': 'name',
#        'alias': 'Name',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'alias',
#        'alias': 'Alias',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'unique_number',
#        'alias': 'Unique Number',
#        'type': 'SHORT',
#        'length': None,
#        'domain': None},
#       {'name': 'status',
#        'alias': 'Status',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'status'},
#       {'name': 'start_date',
#        'alias': 'Start Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'end_date',
#        'alias': 'End Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'class',
#        'alias': 'Class',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'electric_network_class'},
#       {'name': 'subclass',
#        'alias': 'Subclass',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'material',
#        'alias': 'Material',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'material'},
#       {'name': 'notes',
#        'alias': 'Notes',
#        'type': 'TEXT',
#        'length': 1000,
#        'domain': None}],
#      'drawingInfo': {'transparency': 0,
#       'scaleSymbols': True,
#       'renderer': {'type': 'uniqueValue',
#        'field1': 'class',
#        'uniqueValueInfos': [{'value': 'Primary',
#          'symbol': {'type': 'esriSLS',
#           'style': 'esriSLSSolid',
#           'color': [46, 188, 252, 255],
#           'width': 1}}],
#        'defaultLabel': 'Default',
#        'defaultSymbol': {'type': 'esriSLS',
#         'style': 'esriSLSSolid',
#         'color': [250, 250, 250, 255],
#         'width': 1}},
#       'labelingInfo': None}}]},
#   {'name': 'water_utilities',
#    'alias': 'Water Utilities',
#    'tables': ['activities', 'hazards', 'measurements'],
#    'layers': [{'name': 'water_device',
#      'alias': 'Water Device',
#      'type': 'POINT',
#      'children': ['activities', 'hazards'],
#      'fields': [{'name': 'name',
#        'alias': 'Name',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'alias',
#        'alias': 'Alias',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'unique_number',
#        'alias': 'Unique Number',
#        'type': 'SHORT',
#        'length': None,
#        'domain': None},
#       {'name': 'status',
#        'alias': 'Status',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'status'},
#       {'name': 'start_date',
#        'alias': 'Start Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'end_date',
#        'alias': 'End Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'class',
#        'alias': 'Class',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'water_device_class'},
#       {'name': 'subclass',
#        'alias': 'Subclass',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'capacity',
#        'alias': 'Capacity',
#        'type': 'DOUBLE',
#        'length': None,
#        'domain': None},
#       {'name': 'unit',
#        'alias': 'Unit',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'units'},
#       {'name': 'notes',
#        'alias': 'Notes',
#        'type': 'TEXT',
#        'length': 1000,
#        'domain': None}],
#      'drawingInfo': {'transparency': 0,
#       'scaleSymbols': True,
#       'renderer': {'type': 'uniqueValue',
#        'field1': 'class',
#        'uniqueValueInfos': [{'value': 'Primary',
#          'symbol': {'type': 'esriSMS',
#           'style': 'esriSMSCircle',
#           'size': 20,
#           'color': [46, 188, 252, 255],
#           'outline': {'color': [32, 32, 32, 255], 'width': 2}}}],
#        'defaultLabel': 'Default',
#        'defaultSymbol': {'type': 'esriSMS',
#         'style': 'esriSMSCircle',
#         'size': 20,
#         'color': [232, 232, 232, 255],
#         'outline': {'color': [32, 32, 32, 255], 'width': 2}}},
#       'labelingInfo': None}},
#     {'name': 'water_junction',
#      'alias': 'Water Junction',
#      'type': 'POINT',
#      'children': ['activities', 'hazards'],
#      'fields': [{'name': 'name',
#        'alias': 'Name',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'alias',
#        'alias': 'Alias',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'unique_number',
#        'alias': 'Unique Number',
#        'type': 'SHORT',
#        'length': None,
#        'domain': None},
#       {'name': 'status',
#        'alias': 'Status',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'status'},
#       {'name': 'start_date',
#        'alias': 'Start Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'end_date',
#        'alias': 'End Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'class',
#        'alias': 'Class',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'water_junction_class'},
#       {'name': 'subclass',
#        'alias': 'Subclass',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'notes',
#        'alias': 'Notes',
#        'type': 'TEXT',
#        'length': 1000,
#        'domain': None}],
#      'drawingInfo': {'transparency': 0,
#       'scaleSymbols': True,
#       'renderer': {'type': 'uniqueValue',
#        'field1': 'class',
#        'uniqueValueInfos': [{'value': 'Primary',
#          'symbol': {'type': 'esriSMS',
#           'style': 'esriSMSCircle',
#           'size': 20,
#           'color': [46, 188, 252, 255],
#           'outline': {'color': [32, 32, 32, 255], 'width': 2}}}],
#        'defaultLabel': 'Default',
#        'defaultSymbol': {'type': 'esriSMS',
#         'style': 'esriSMSCircle',
#         'size': 20,
#         'color': [232, 232, 232, 255],
#         'outline': {'color': [32, 32, 32, 255], 'width': 2}}},
#       'labelingInfo': None}},
#     {'name': 'water_structure',
#      'alias': 'Water Structure',
#      'type': 'POINT',
#      'children': ['activities', 'hazards'],
#      'fields': [{'name': 'name',
#        'alias': 'Name',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'alias',
#        'alias': 'Alias',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'unique_number',
#        'alias': 'Unique Number',
#        'type': 'SHORT',
#        'length': None,
#        'domain': None},
#       {'name': 'status',
#        'alias': 'Status',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'status'},
#       {'name': 'start_date',
#        'alias': 'Start Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'end_date',
#        'alias': 'End Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'class',
#        'alias': 'Class',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'water_junction_class'},
#       {'name': 'subclass',
#        'alias': 'Subclass',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'notes',
#        'alias': 'Notes',
#        'type': 'TEXT',
#        'length': 1000,
#        'domain': None}],
#      'drawingInfo': {'transparency': 0,
#       'scaleSymbols': True,
#       'renderer': {'type': 'uniqueValue',
#        'field1': 'class',
#        'uniqueValueInfos': [{'value': 'Primary',
#          'symbol': {'type': 'esriSMS',
#           'style': 'esriSMSCircle',
#           'size': 20,
#           'color': [46, 188, 252, 255],
#           'outline': {'color': [32, 32, 32, 255], 'width': 2}}}],
#        'defaultLabel': 'Default',
#        'defaultSymbol': {'type': 'esriSMS',
#         'style': 'esriSMSCircle',
#         'size': 20,
#         'color': [232, 232, 232, 255],
#         'outline': {'color': [32, 32, 32, 255], 'width': 2}}},
#       'labelingInfo': None}},
#     {'name': 'water_network',
#      'alias': 'Water Network',
#      'type': 'POLYLINE',
#      'children': ['activities', 'hazards'],
#      'fields': [{'name': 'name',
#        'alias': 'Name',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'alias',
#        'alias': 'Alias',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'unique_number',
#        'alias': 'Unique Number',
#        'type': 'SHORT',
#        'length': None,
#        'domain': None},
#       {'name': 'status',
#        'alias': 'Status',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'status'},
#       {'name': 'start_date',
#        'alias': 'Start Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'end_date',
#        'alias': 'End Date',
#        'type': 'DATE',
#        'length': None,
#        'domain': None},
#       {'name': 'class',
#        'alias': 'Class',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'water_network_class'},
#       {'name': 'subclass',
#        'alias': 'Subclass',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'capacity',
#        'alias': 'Capacity',
#        'type': 'DOUBLE',
#        'length': None,
#        'domain': None},
#       {'name': 'unit',
#        'alias': 'Unit',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'units'},
#       {'name': 'material',
#        'alias': 'Material',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': 'material'},
#       {'name': 'notes',
#        'alias': 'Notes',
#        'type': 'TEXT',
#        'length': 1000,
#        'domain': None}],
#      'drawingInfo': {'transparency': 0,
#       'scaleSymbols': True,
#       'renderer': {'type': 'uniqueValue',
#        'field1': 'class',
#        'uniqueValueInfos': [{'value': 'Primary',
#          'symbol': {'type': 'esriSLS',
#           'style': 'esriSLSSolid',
#           'color': [46, 188, 252, 255],
#           'width': 1}}],
#        'defaultLabel': 'Default',
#        'defaultSymbol': {'type': 'esriSLS',
#         'style': 'esriSLSSolid',
#         'color': [250, 250, 250, 255],
#         'width': 1}},
#       'labelingInfo': None}}]},
#   {'name': 'effluent_utilities',
#    'alias': 'Effluent Utilities',
#    'tables': ['activities', 'hazards', 'measurements'],
#    'layers': [{'name': 'effluent_device',
#      'alias': 'Effluent Device',
#      'type': 'POINT',
#      'children': ['activities', 'hazards'],
#      'fields': [{'name': 'name',
#        'alias': 'Name',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
#       {'name': 'alias',
#        'alias': 'Alias',
#        'type': 'TEXT',
#        'length': 255,
#        'domain': None},
# ...
#      'type': 'SHORT',
#      'length': None,
#      'domain': None},
#     {'name': 'start_date',
#      'alias': 'Start Date',
#      'type': 'DATE',
#      'length': None,
#      'domain': None},
#     {'name': 'end_date',
#      'alias': 'End Date',
#      'type': 'DATE',
#      'length': None,
#      'domain': None},
#     {'name': 'type',
#      'alias': 'Type',
#      'type': 'TEXT',
#      'length': 255,
#      'domain': 'activity_type'},
#     {'name': 'description',
#      'alias': 'Description',
#      'type': 'TEXT',
#      'length': 1000,
#      'domain': None},
#     {'name': 'estimated_cost',
#      'alias': 'Estimated Cost',
#      'type': 'DOUBLE',
#      'length': None,
#      'domain': None},
#     {'name': 'actual_cost',
#      'alias': 'Actual Cost',
#      'type': 'DOUBLE',
#      'length': None,
#      'domain': None},
#     {'name': 'responsibility_of',
#      'alias': 'Responsibility Of',
#      'type': 'TEXT',
#      'length': 255,
#      'domain': 'responsibility_of'},
#     {'name': 'action_date',
#      'alias': 'Action Date',
#      'type': 'DATE',
#      'length': None,
#      'domain': None},
#     {'name': 'stage',
#      'alias': 'Stage',
#      'type': 'TEXT',
#      'length': 255,
#      'domain': 'stage'},
#     {'name': 'notes',
#      'alias': 'Notes',
#      'type': 'TEXT',
#      'length': 1000,
#      'domain': None}]},
#   {'name': 'hazards',
#    'alias': 'Hazards',
#    'type': 'TABLE',
#    'children': [],
#    'fields': [{'name': 'name',
#      'alias': 'Name',
#      'type': 'TEXT',
#      'length': 255,
#      'domain': None},
#     {'name': 'alias',
#      'alias': 'Alias',
#      'type': 'TEXT',
#      'length': 255,
#      'domain': None},
#     {'name': 'start_date',
#      'alias': 'Start Date',
#      'type': 'DATE',
#      'length': None,
#      'domain': None},
#     {'name': 'end_date',
#      'alias': 'End Date',
#      'type': 'DATE',
#      'length': None,
#      'domain': None},
#     {'name': 'notes',
#      'alias': 'Notes',
#      'type': 'TEXT',
#      'length': 1000,
#      'domain': None}]},
#   {'name': 'measurements',
#    'alias': 'Measurements',
#    'type': 'TABLE',
#    'children': [],
#    'fields': [{'name': 'name',
#      'alias': 'Name',
#      'type': 'TEXT',
#      'length': 255,
#      'domain': None},
#     {'name': 'alias',
#      'alias': 'Alias',
#      'type': 'TEXT',
#      'length': 255,
#      'domain': None},
#     {'name': 'unique_number',
#      'alias': 'Unique Number',
#      'type': 'SHORT',
#      'length': None,
#      'domain': None},
#     {'name': 'start_date',
#      'alias': 'Start Date',
#      'type': 'DATE',
#      'length': None,
#      'domain': None},
#     {'name': 'end_date',
#      'alias': 'End Date',
#      'type': 'DATE',
#      'length': None,
#      'domain': None},
#     {'name': 'type',
#      'alias': 'Type',
#      'type': 'TEXT',
#      'length': 255,
#      'domain': None},
#     {'name': 'measurement',
#      'alias': 'Measurement',
#      'type': 'DOUBLE',
#      'length': None,
#      'domain': None},
#     {'name': 'unit',
#      'alias': 'Unit',
#      'type': 'TEXT',
#      'length': 255,
#      'domain': 'units'},
#     {'name': 'notes',
#      'alias': 'Notes',
#      'type': 'TEXT',
#      'length': 1000,
#      'domain': None}]},
#   {'name': 'additional_details',
#    'alias': 'Additional Details',
#    'type': 'TABLE',
#    'children': [],
#    'fields': [{'name': 'name',
#      'alias': 'Name',
#      'type': 'TEXT',
#      'length': 255,
#      'domain': None},
#     {'name': 'alias',
#      'alias': 'Alias',
#      'type': 'TEXT',
#      'length': 255,
#      'domain': None},
#     {'name': 'unique_number',
#      'alias': 'Unique Number',
#      'type': 'SHORT',
#      'length': None,
#      'domain': None},
#     {'name': 'start_date',
#      'alias': 'Start Date',
#      'type': 'DATE',
#      'length': None,
#      'domain': None},
#     {'name': 'end_date',
#      'alias': 'End Date',
#      'type': 'DATE',
#      'length': None,
#      'domain': None},
#     {'name': 'class',
#      'alias': 'Class',
#      'type': 'TEXT',
#      'length': 255,
#      'domain': 'detail_class'},
#     {'name': 'subclass',
#      'alias': 'Subclass',
#      'type': 'TEXT',
#      'length': 255,
#      'domain': 'primary_secondary'},
#     {'name': 'link',
#      'alias': 'Link',
#      'type': 'TEXT',
#      'length': 1000,
#      'domain': None},
#     {'name': 'notes',
#      'alias': 'Notes',
#      'type': 'TEXT',
#      'length': 1000,
#      'domain': None}]},
#   {'name': 'staff',
#    'alias': 'Staff',
#    'type': 'TABLE',
#    'children': [],
#    'fields': [{'name': 'name',
#      'alias': 'Name',
#      'type': 'TEXT',
#      'length': 255,
#      'domain': None},
#     {'name': 'alias',
#      'alias': 'Alias',
#      'type': 'TEXT',
#      'length': 255,
#      'domain': None},
#     {'name': 'unique_number',
#      'alias': 'Unique Number',
#      'type': 'SHORT',
#      'length': None,
#      'domain': None},
#     {'name': 'role',
#      'alias': 'Role',
#      'type': 'TEXT',
#      'length': 255,
#      'domain': 'role'},
#     {'name': 'contact_number',
#      'alias': 'Contact Number',
#      'type': 'TEXT',
#      'length': 255,
#      'domain': None},
#     {'name': 'notes',
#      'alias': 'Notes',
#      'type': 'TEXT',
#      'length': 1000,
#      'domain': None}]},
#   {'name': 'injuries',
#    'alias': 'Injuries',
#    'type': 'TABLE',
#    'children': [],
#    'fields': [{'name': 'name',
#      'alias': 'Name',
#      'type': 'TEXT',
#      'length': 255,
#      'domain': None},
#     {'name': 'alias',
#      'alias': 'Alias',
#      'type': 'TEXT',
#      'length': 255,
#      'domain': None},
#     {'name': 'unique_number',
#      'alias': 'Unique Number',
#      'type': 'SHORT',
#      'length': None,
#      'domain': None},
#     {'name': 'class',
#      'alias': 'Injury Class',
#      'type': 'TEXT',
#      'length': 255,
#      'domain': 'injury_class'},
#     {'name': 'body_part',
#      'alias': 'Body Part',
#      'type': 'TEXT',
#      'length': 255,
#      'domain': 'body_part'},
#     {'name': 'notes',
#      'alias': 'Notes',
#      'type': 'TEXT',
#      'length': 1000,
#      'domain': None}]}],
#  'domains': [{'name': 'yes_no',
#    'workspace': ['*'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Yes': 'Yes', 'No': 'No'}},
#   {'name': 'primary_secondary',
#    'workspace': ['*'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Primary': 'Primary', 'Secondary': 'Secondary'}},
#   {'name': 'units',
#    'workspace': ['*'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'units': 'units',
#     'millimetre': 'millimetres',
#     'centimeter': 'centimeters',
#     'meters': 'meters',
#     'kilometers': 'kilometers',
#     'kilogram': 'kilograms',
#     'tonne': 'tonnes',
#     'litre': 'litres',
#     'cubic metre': 'cubic metres'}},
#   {'name': 'status',
#    'workspace': ['*'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Current': 'Current',
#     'Proposed': 'Proposed',
#     'Temporary': 'Temporary',
#     'Historic': 'Historic'}},
#   {'name': 'material',
#    'workspace': ['*'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Concrete': 'Concrete',
#     'Polyurethane': 'Polyurethane',
#     'Wood': 'Wood',
#     'Metal': 'Metal'}},
#   {'name': 'stage',
#    'workspace': ['*'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Suggested': 'Suggested',
#     'Progressing': 'Progressing',
#     'Completed': 'Completed'}},
#   {'name': 'activity_type',
#    'workspace': ['*'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Action': 'Action', 'Routine': 'Routine'}},
#   {'name': 'phase',
#    'workspace': ['*'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Suggested': 'Suggested',
#     'Progressing': 'Progressing',
#     'Completed': 'Completed'}},
#   {'name': 'site_class',
#    'workspace': ['administrative_information'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Dairy': 'Dairy',
#     'Dry Stock': 'Dry Stock',
#     'Forestry': 'Forestry',
#     'Horticulture': 'Horticulture'}},
#   {'name': 'block_class',
#    'workspace': ['administrative_information'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Paddock': 'Paddock',
#     'Transport Corridor': 'Transport Corridor',
#     'Waterway Corridor': 'Waterway Corridor',
#     'Supplement Paddock': 'Supplement Paddock',
#     'Forestry Stand': 'Forestry Stand',
#     'Residential': 'Residential'}},
#   {'name': 'detail_class',
#    'workspace': ['administrative_information'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'A2 Supplier': 'A2 Supplier',
#     'Vet': 'Vet',
#     'Chemical Company': 'Chemical Company',
#     'Monitoring System': 'Monitoring System',
#     'Cooling System': 'Cooling System',
#     'Plant Wast System': 'Plant Wast System',
#     'Internal Record': 'Internal Record'}},
#   {'name': 'production_structure_class',
#    'workspace': ['structures'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Dairy Shed': 'Dairy Shed'}},
#   {'name': 'production_structure_subclass',
#    'workspace': ['structures'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'High Line Herringbone': 'High Line Herringbone',
#     'External Rotary': 'External Rotary',
#     'Internal Rotary': 'Internal Rotary'}},
#   {'name': 'content_type',
#    'workspace': ['structures'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Milk': 'Milk',
#     'Chemical': 'Chemical',
#     'Fertiliser': 'Fertiliser',
#     'Fuel': 'Fuel',
#     'Silage': 'Silage',
#     'Grain': 'Grain',
#     'Hay': 'Hay',
#     'Wood': 'Wood'}},
#   {'name': 'storage_structure_class',
#    'workspace': ['structures'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Vat': 'Vat',
#     'Silo': 'Silo',
#     'Tank': 'Tank',
#     'Pit': 'Pit',
#     'Shed': 'Shed'}},
#   {'name': 'service_structure_class',
#    'workspace': ['structures'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Stock Yard': 'Stock Yard',
#     'Loading Ramp': 'Loading Ramp',
#     'Utilities Shed': 'Utilities Shed'}},
#   {'name': 'management_structure_class',
#    'workspace': ['structures'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Residential': 'Residential', 'Office': 'Office'}},
#   {'name': 'waste_structure_class',
#    'workspace': ['structures'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Rubbish Pit': 'Rubbish Pit',
#     'Offal Pit': 'Offal Pit',
#     'Recycling': 'Recycling'}},
#   {'name': 'operation_type',
#    'workspace': ['operations'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Irrigation': 'Irrigation',
#     'Effluent': 'Effluent',
#     'Fertiliser': 'Fertiliser',
#     'Pest Control': 'Pest Control',
#     'Other': 'Other'}},
#   {'name': 'transport_node_class',
#    'workspace': ['transport'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Bridge': 'Bridge',
#     'Cattlestop': 'Cattlestop',
#     'Culvert': 'Culvert',
#     'Gate': 'Gate',
#     'Road Crossing': 'Road Crossing'}},
#   {'name': 'electric_device_class',
#    'workspace': ['electric_utilities'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Energizer': 'Energizer'}},
#   {'name': 'electric_structure_class',
#    'workspace': ['electric_utilities'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Power Pole': 'Power Pole'}},
#   {'name': 'electric_network_class',
#    'workspace': ['electric_utilities'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Electric Fence': 'Electric Fence',
#     'Overhead Power Line': 'Overhead Power Line',
#     'Underground Power Line': 'Underground Power Line'}},
#   {'name': 'water_device_class',
#    'workspace': ['water_utilities'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Irrigation System': 'Irrigation System',
#     'Water Pump': 'Water Pump',
#     'Water Trough': 'Water Trough',
#     'Water Tank': 'Water Tank',
#     'Well': 'Well'}},
#   {'name': 'water_network_class',
#    'workspace': ['water_utilities'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Pipe': 'Pipe'}},
#   {'name': 'effluent_device_class',
#    'workspace': ['effluent_utilities'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Effluent Pond': 'Effluent Pond',
#     'Effluent System': 'Effluent Pump'}},
#   {'name': 'effluent_network_class',
#    'workspace': ['effluent_utilities'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Pipe': 'Pipe'}},
#   {'name': 'topographic_point_class',
#    'workspace': ['topographic_features'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Tree': 'Tree', 'Dam': 'Dam', 'Cliff': 'Cliff'}},
#   {'name': 'topographic_line_class',
#    'workspace': ['topographic_features'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Hedge': 'Hedge'}},
#   {'name': 'topographic_area_class',
#    'workspace': ['topographic_features'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Native Vegetation': 'Native Vegetation',
#     'Exotic Vegetation': 'Exotic Vegetation',
#     'Wetland': 'Wetland',
#     'Gulley': 'Gulley',
#     'Swale': 'Swale'}},
#   {'name': 'water_class',
#    'workspace': ['water'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Artificial': 'Artificial',
#     'Ephemeral': 'Ephemeral',
#     'Intermittent': 'Intermittent',
#     'Permanent': 'Permanent'}},
#   {'name': 'slope_class',
#    'workspace': ['land'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Flat to Gently Undulating': 'Flat to Gently Undulating',
#     'Undulating': 'Undulating',
#     'Rolling': 'Rolling',
#     'Strongly Rolling': 'Strongly Rolling',
#     'Moderately Steep': 'Moderately Steep',
#     'Steep': 'Steep',
#     'Very Steep': 'Very Steep'}},
#   {'name': 'slope_class_range',
#    'workspace': ['land'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'0â€“3Â°': '0â€“3Â°',
#     '4â€“7Â°': '4â€“7Â°',
#     '8â€“15Â°': '8â€“15Â°',
#     '16â€“20Â°': '16â€“20Â°',
#     '21â€“25Â°': '21â€“25Â°',
#     '26â€“35Â°': '26â€“35Â°',
#     '>35Â°': '>35Â°'}},
#   {'name': 'instrument_class',
#    'workspace': ['instruments'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Rain Gauge': 'Rain Gauge',
#     'River Flow Gauge': 'River Flow Gauge',
#     'Soil Moisture Probe': 'Soil Moisture Probe',
#     'Soil Nutrient Test': 'Soil Nutrient Test',
#     'Weather Station': 'Weather Station'}},
#   {'name': 'injury_class',
#    'workspace': ['health_and_safety'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Strain/Sprain': 'Strain/Sprain',
#     'Cut': 'Cut',
#     'Head Injury': 'Head Injury',
#     'Fracture/Break': 'Fracture/Break',
#     'Bruising': 'Bruising',
#     'Burn': 'Burn',
#     'Poison/Chemical': 'Poison/Chemical'}},
#   {'name': 'body_part',
#    'workspace': ['health_and_safety'],
#    'description': None,
#    'field_type': 'TEXT',
#    'domain_type': 'CODED',
#    'codes': {'Face': 'Face',
#     'Head': 'Head',
#     'Back': 'Back',
#     'Torso': 'Torso',
#     'Front Right Arm': 'Front Right Arm',
#     'Back Right Arm': 'Back Right Arm',
#     'Front Left Arm': 'Front Left Arm',
#     'Back Left Arm': 'Back Left Arm',
#     'Front Left Leg': 'Front Left Leg',
#     'Front Right Leg': 'Front Right Leg',
#     'Palm Right Hand': 'Palm Right Hand',
#     'Palm Left Hand': 'Palm Left Hand',
#     'Back Left Hand': 'Back Left Hand',
#     'Back Right Hand': 'Back Right Hand',
#     'Back Left Leg': 'Back Left Leg',
#     'Back Right Leg': 'Back Right Leg'}}]}

# %% [markdown]
# #### Export to Excel

# %%
headers = ['Service Name', 'Layer Name', 'Field Name', 'Codes', 'Type']
csvRow = []
csvRow.append(headers)
csvRow.append(' ')

for service in data['services']:
    
    print(service['alias'])
    csvRow.append([service['alias']])
    csvRow.append(' ')
    
    for layer in service['layers']:
        
        children = '; '.join([x.replace('_', ' ').title() for x in layer['children']])
        
        print('  - {0}'.format(layer['alias']))   
        print('    - Children: {0}'.format(children))
        
        csvRow.append([' ', layer['alias']])
        csvRow.append([' ', ' ', 'Children', children])
        
        if layer['fields'] != None:
            
            for field in layer['fields']:

                domains = [x for x in data['domains'] if field['domain'] == x['name']]
                if domains != []:
                    codes = list(domains[0]['codes'].values())
                else:
                    codes = '-'

                print('     - {0}: {1} | {2}'.format(field['alias'], '; '.join(codes), field['type']))
                csvRow.append([' ', ' ', field['alias'], '; '.join(codes), field['type']])
                
        else:
            
            table = [x for x in data['tables'] if layer['master'] == x['name']][0]
            
            for field in table['fields']:

                domains = [x for x in data['domains'] if field['domain'] == x['name']]
                if domains != []:
                    codes = list(domains[0]['codes'].values())
                else:
                    codes = '-'

                print('     - {0}: {1} | {2}'.format(field['alias'], '; '.join(codes), field['type']))
                csvRow.append([' ', ' ', field['alias'], '; '.join(codes), field['type']])            
        
            
        csvRow.append(' ')        
        print(' ')  
        
           
print('Common Tables')
csvRow.append(['Common Tables'])
csvRow.append(' ')

for table in data['tables']:

    print('  - {0}'.format(table['alias']))   
    csvRow.append([' ', table['alias']])

    for field in table['fields']:

        domains = [x for x in data['domains'] if field['domain'] == x['name']]
        if domains != []:
            codes = list(domains[0]['codes'].values())
        else:
            codes = '-'

        print('     - {0}: {1} | {2}'.format(field['alias'], '; '.join(codes), field['type']))
        csvRow.append([' ', ' ', field['alias'], '; '.join(codes), field['type']])    

    csvRow.append(' ')        
    print(' ')  
    
        
outputFile = '{0}\\output\\dictionary\\{1}.csv'.format(basePath, 'datadictionary')
with open(outputFile, 'w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerows(csvRow)
# Out:
# Administrative Information
#   - Access Points
#     - Children: Activities
#      - Address: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: Primary; Secondary | TEXT
#      - Notes: - | TEXT
#
#   - Blocks
#     - Children: Activities
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: Paddock; Transport Corridor; Waterway Corridor; Supplement Paddock; Forestry Stand; Residential | TEXT
#      - Subclass: - | TEXT
#      - Productive: Yes; No | TEXT
#      - Protected: Yes; No | TEXT
#      - Notes: - | TEXT
#
#   - Site
#     - Children: Blocks; Access Points; Activities; Additional Details; Measurements; Staff
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: Dairy; Dry Stock; Forestry; Horticulture | TEXT
#      - Subclass: Primary; Secondary | TEXT
#      - Capacity: - | SHORT
#      - Unit: units; millimetres; centimeters; meters; kilometers; kilograms; tonnes; litres; cubic metres | TEXT
#      - Usage: - | TEXT
#      - Notes: - | TEXT
#
#   - Holding
#     - Children: Site
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Owner: - | TEXT
#      - Titles: - | TEXT
#      - Notes: - | TEXT
#
# Structures
#   - Production Structures
#     - Children: Activities; Additional Details; Hazards; Measurements
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: Dairy Shed | TEXT
#      - Subclass: High Line Herringbone; External Rotary; Internal Rotary | TEXT
#      - Capacity: - | DOUBLE
#      - Unit: units; millimetres; centimeters; meters; kilometers; kilograms; tonnes; litres; cubic metres | TEXT
#      - Usage: - | TEXT
#      - Material: Concrete; Polyurethane; Wood; Metal | TEXT
#      - Notes: - | TEXT
#
#   - Storage Structures
#     - Children: Activities; Hazards; Measurements
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Content: Milk; Chemical; Fertiliser; Fuel; Silage; Grain; Hay; Wood | TEXT
#      - Class: Vat; Silo; Tank; Pit; Shed | TEXT
#      - Subclass: - | TEXT
#      - Capacity: - | DOUBLE
#      - Unit: units; millimetres; centimeters; meters; kilometers; kilograms; tonnes; litres; cubic metres | TEXT
#      - Usage: - | TEXT
#      - Material: Concrete; Polyurethane; Wood; Metal | TEXT
#      - Notes: - | TEXT
#
#   - Service Structures
#     - Children: Activities; Hazards; Measurements
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: Stock Yard; Loading Ramp; Utilities Shed | TEXT
#      - Subclass: - | TEXT
#      - Capacity: - | DOUBLE
#      - Unit: units; millimetres; centimeters; meters; kilometers; kilograms; tonnes; litres; cubic metres | TEXT
#      - Usage: - | TEXT
#      - Material: Concrete; Polyurethane; Wood; Metal | TEXT
#      - Notes: - | TEXT
#
#   - Management Structures
#     - Children: Activities; Hazards; Measurements
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: Residential; Office | TEXT
#      - Subclass: - | TEXT
#      - Usage: - | TEXT
#      - Material: Concrete; Polyurethane; Wood; Metal | TEXT
#      - Notes: - | TEXT
#
#   - Waste Structures
#     - Children: Activities; Hazards; Measurements
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: Rubbish Pit; Offal Pit; Recycling | TEXT
#      - Subclass: - | TEXT
#      - Capacity: - | DOUBLE
#      - Unit: units; millimetres; centimeters; meters; kilometers; kilograms; tonnes; litres; cubic metres | TEXT
#      - Usage: - | TEXT
#      - Material: Concrete; Polyurethane; Wood; Metal | TEXT
#      - Notes: - | TEXT
#
# Operations
#   - Operational Points
#     - Children: Activities; Hazards
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: Irrigation; Effluent; Fertiliser; Pest Control; Other | TEXT
#      - Subclass: - | TEXT
#      - Notes: - | TEXT
#
#   - Operational Lines
#     - Children: Activities; Hazards
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: Irrigation; Effluent; Fertiliser; Pest Control; Other | TEXT
#      - Subclass: - | TEXT
#      - Notes: - | TEXT
#
#   - Operational Areas
#     - Children: Activities; Hazards
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: Irrigation; Effluent; Fertiliser; Pest Control; Other | TEXT
#      - Subclass: - | TEXT
#      - Notes: - | TEXT
#
# Transport
#   - Transport Node
#     - Children: Activities; Hazards
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: Bridge; Cattlestop; Culvert; Gate; Road Crossing | TEXT
#      - Subclass: - | TEXT
#      - Capacity: - | DOUBLE
#      - Unit: units; millimetres; centimeters; meters; kilometers; kilograms; tonnes; litres; cubic metres | TEXT
#      - Material: Concrete; Polyurethane; Wood; Metal | TEXT
#      - Notes: - | TEXT
#
#   - Transport Network
#     - Children: Activities; Hazards
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: Primary; Secondary | TEXT
#      - Subclass: - | TEXT
#      - Material: Concrete; Polyurethane; Wood; Metal | TEXT
#      - Notes: - | TEXT
#
# Electric Utilities
#   - Electric Device
#     - Children: Activities; Hazards
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: Energizer | TEXT
#      - Subclass: - | TEXT
#      - Capacity: - | DOUBLE
#      - Unit: units; millimetres; centimeters; meters; kilometers; kilograms; tonnes; litres; cubic metres | TEXT
#      - Notes: - | TEXT
#
#   - Electric Junction
#     - Children: Activities; Hazards
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: - | TEXT
#      - Subclass: - | TEXT
#      - Material: Concrete; Polyurethane; Wood; Metal | TEXT
#      - Notes: - | TEXT
#
#   - Electric Structure
#     - Children: Activities; Hazards
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: Power Pole | TEXT
#      - Subclass: - | TEXT
#      - Material: Concrete; Polyurethane; Wood; Metal | TEXT
#      - Notes: - | TEXT
#
#   - Electric Network
#     - Children: Activities; Hazards
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: Electric Fence; Overhead Power Line; Underground Power Line | TEXT
#      - Subclass: - | TEXT
#      - Material: Concrete; Polyurethane; Wood; Metal | TEXT
#      - Notes: - | TEXT
#
# Water Utilities
#   - Water Device
#     - Children: Activities; Hazards
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: Irrigation System; Water Pump; Water Trough; Water Tank; Well | TEXT
#      - Subclass: - | TEXT
#      - Capacity: - | DOUBLE
#      - Unit: units; millimetres; centimeters; meters; kilometers; kilograms; tonnes; litres; cubic metres | TEXT
#      - Notes: - | TEXT
#
#   - Water Junction
#     - Children: Activities; Hazards
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: - | TEXT
#      - Subclass: - | TEXT
#      - Notes: - | TEXT
#
#   - Water Structure
#     - Children: Activities; Hazards
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: - | TEXT
#      - Subclass: - | TEXT
#      - Notes: - | TEXT
#
#   - Water Network
#     - Children: Activities; Hazards
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: Pipe | TEXT
#      - Subclass: - | TEXT
#      - Capacity: - | DOUBLE
#      - Unit: units; millimetres; centimeters; meters; kilometers; kilograms; tonnes; litres; cubic metres | TEXT
#      - Material: Concrete; Polyurethane; Wood; Metal | TEXT
#      - Notes: - | TEXT
#
# Effluent Utilities
#   - Effluent Device
#     - Children: Activities; Hazards
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: Effluent Pond; Effluent Pump | TEXT
#      - Subclass: - | TEXT
#      - Capacity: - | DOUBLE
#      - Unit: units; millimetres; centimeters; meters; kilometers; kilograms; tonnes; litres; cubic metres | TEXT
#      - Notes: - | TEXT
#
#   - Effluent Junction
#     - Children: Activities; Hazards
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: - | TEXT
#      - Subclass: - | TEXT
#      - Notes: - | TEXT
#
#   - Effluent Network
#     - Children: Activities; Hazards
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: Pipe | TEXT
#      - Subclass: - | TEXT
#      - Capacity: - | DOUBLE
#      - Unit: units; millimetres; centimeters; meters; kilometers; kilograms; tonnes; litres; cubic metres | TEXT
#      - Material: Concrete; Polyurethane; Wood; Metal | TEXT
#      - Notes: - | TEXT
#
# Topographic Features
#   - Topographic Points
#     - Children: Activities; Hazards
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: Tree; Dam; Cliff | TEXT
#      - Subclass: - | TEXT
#      - Notes: - | TEXT
#
#   - Topographic Lines
#     - Children: Activities; Hazards
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: Hedge | TEXT
#      - Subclass: - | TEXT
#      - Notes: - | TEXT
#
#   - Topographic Areas
#     - Children: Activities; Hazards
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: Native Vegetation; Exotic Vegetation; Wetland; Gulley; Swale | TEXT
#      - Subclass: - | TEXT
#      - Notes: - | TEXT
#
# Miscellaneous
#   - Point of Interest
#     - Children: Activities; Hazards
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: - | TEXT
#      - Subclass: - | TEXT
#      - Notes: - | TEXT
#
#   - Line of Interest
#     - Children: Activities; Hazards
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: - | TEXT
#      - Subclass: - | TEXT
#      - Notes: - | TEXT
#
#   - Area of Interest
#     - Children: Activities; Hazards
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: - | TEXT
#      - Subclass: - | TEXT
#      - Notes: - | TEXT
#
# Water
#   - Waterways
#     - Children: Activities; Hazards
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: Artificial; Ephemeral; Intermittent; Permanent | TEXT
#      - Notes: - | TEXT
#
#   - Water Bodies
#     - Children: Activities; Hazards
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: Artificial; Ephemeral; Intermittent; Permanent | TEXT
#      - Notes: - | TEXT
#
#   - Catchment
#     - Children: Waterbodies; Waterways
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Notes: - | TEXT
#
# Land
#   - Slope
#     - Children:
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Class: Flat to Gently Undulating; Undulating; Rolling; Strongly Rolling; Moderately Steep; Steep; Very Steep | TEXT
#      - Class Range: 0â€“3Â°; 4â€“7Â°; 8â€“15Â°; 16â€“20Â°; 21â€“25Â°; 26â€“35Â°; >35Â° | TEXT
#      - Notes: - | TEXT
#
# Insights
#   - Instruments
#     - Children: Measurements; Activities; Hazards
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: Rain Gauge; River Flow Gauge; Soil Moisture Probe; Soil Nutrient Test; Weather Station | TEXT
#      - Subclass: - | TEXT
#      - Notes: - | TEXT
#
#   - Field Measurement
#     - Children: Measurements; Activities; Hazards
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Status: Current; Proposed; Temporary; Historic | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: Rain Gauge; River Flow Gauge; Soil Moisture Probe; Soil Nutrient Test; Weather Station | TEXT
#      - Subclass: - | TEXT
#      - Notes: - | TEXT
#
# Activities
#   - Point Activities
#     - Children:
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Type: Action; Routine | TEXT
#      - Description: - | TEXT
#      - Estimated Cost: - | DOUBLE
#      - Actual Cost: - | DOUBLE
#      - Responsibility Of: - | TEXT
#      - Action Date: - | DATE
#      - Stage: Suggested; Progressing; Completed | TEXT
#      - Notes: - | TEXT
#
#   - Line Activities
#     - Children:
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Type: Action; Routine | TEXT
#      - Description: - | TEXT
#      - Estimated Cost: - | DOUBLE
#      - Actual Cost: - | DOUBLE
#      - Responsibility Of: - | TEXT
#      - Action Date: - | DATE
#      - Stage: Suggested; Progressing; Completed | TEXT
#      - Notes: - | TEXT
#
#   - Polygon Activities
#     - Children:
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Type: Action; Routine | TEXT
#      - Description: - | TEXT
#      - Estimated Cost: - | DOUBLE
#      - Actual Cost: - | DOUBLE
#      - Responsibility Of: - | TEXT
#      - Action Date: - | DATE
#      - Stage: Suggested; Progressing; Completed | TEXT
#      - Notes: - | TEXT
#
# Health and Safety
#   - Point Hazards
#     - Children:
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Notes: - | TEXT
#
#   - Line Hazards
#     - Children:
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Notes: - | TEXT
#
#   - Polygon Hazards
#     - Children:
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Notes: - | TEXT
#
#   - Incidents
#     - Children: Injuries
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: - | TEXT
#      - Subclass: - | TEXT
#      - Notes: - | TEXT
#
# Common Tables
#   - Activities
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Type: Action; Routine | TEXT
#      - Description: - | TEXT
#      - Estimated Cost: - | DOUBLE
#      - Actual Cost: - | DOUBLE
#      - Responsibility Of: - | TEXT
#      - Action Date: - | DATE
#      - Stage: Suggested; Progressing; Completed | TEXT
#      - Notes: - | TEXT
#
#   - Hazards
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Notes: - | TEXT
#
#   - Measurements
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Type: - | TEXT
#      - Measurement: - | DOUBLE
#      - Unit: units; millimetres; centimeters; meters; kilometers; kilograms; tonnes; litres; cubic metres | TEXT
#      - Notes: - | TEXT
#
#   - Additional Details
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Start Date: - | DATE
#      - End Date: - | DATE
#      - Class: A2 Supplier; Vet; Chemical Company; Monitoring System; Cooling System; Plant Wast System; Internal Record | TEXT
#      - Subclass: Primary; Secondary | TEXT
#      - Link: - | TEXT
#      - Notes: - | TEXT
#
#   - Staff
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Role: - | TEXT
#      - Contact Number: - | TEXT
#      - Notes: - | TEXT
#
#   - Injuries
#      - Name: - | TEXT
#      - Alias: - | TEXT
#      - Unique Number: - | SHORT
#      - Injury Class: Strain/Sprain; Cut; Head Injury; Fracture/Break; Bruising; Burn; Poison/Chemical | TEXT
#      - Body Part: Face; Head; Back; Torso; Front Right Arm; Back Right Arm; Front Left Arm; Back Left Arm; Front Left Leg; Front Right Leg; Palm Right Hand; Palm Left Hand; Back Left Hand; Back Right Hand; Back Left Leg; Back Right Leg | TEXT
#      - Notes: - | TEXT
